# %% [markdown]
# <a href="https://colab.research.google.com/github/vivek45-guru-cell/Machine-Learning-Projects/blob/main/heartdiseaseML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path="/content/drive/MyDrive/Dataset/heartdisease.csv"
df=pd.read_csv(path)
df
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     60    1   3     145   233    1        0       150     0      2.3    0
# 1     35    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     55    1   1     120   236    0        1       178     0      0.8    2
# 4     56    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 284   60    1   0     140   207    0        0       138     1      1.9    2
# 285   46    1   0     140   311    0        1       120     1      1.8    1
# 286   59    1   3     134   204    0        1       162     0      0.8    2
# 287   54    1   1     154   232    0        0       164     0      0.0    2
# 288   53    1   0     110   335    0        1       143     1      3.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.tail()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 284   60    1   0     140   207    0        0       138     1      1.9    2
# 285   46    1   0     140   311    0        1       120     1      1.8    1
# 286   59    1   3     134   204    0        1       162     0      0.8    2
# 287   54    1   1     154   232    0        0       164     0      0.0    2
# 288   53    1   0     110   335    0        1       143     1      3.0    1
#
#      caa  thall  output
# 284    1      3       0
# 285    2      3       0
# 286    2      2       0
# 287    1      2       0
# 288    1      3       0

# %%
df.shape
# Out:
# (289, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 289 entries, 0 to 288
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       289 non-null    int64
#  1   sex       289 non-null    int64
#  2   cp        289 non-null    int64
#  3   trtbps    289 non-null    int64
#  4   chol      289 non-null    int64
#  5   fbs       289 non-null    int64
#  6   restecg   289 non-null    int64
#  7   thalachh  289 non-null    int64
#  8   exng      289 non-null    int64
#  9   oldpeak   289 non-null    float64
#  10  slp       289 non-null    int64
#  11  caa       289 non-null    int64
#  12  thall     289 non-null    int64
#  13  output    289 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 31.7 KB

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
dp_value=df.duplicated().any()
print(dp_value)
# Out:
# True

# %%
df=df.drop_duplicates()
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   60    1   3     145   233    1        0       150     0      2.3    0
# 1   35    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   55    1   1     120   236    0        1       178     0      0.8    2
# 4   56    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.shape
# Out:
# (288, 14)

# %%
df.corr()
# Out:
#                age       sex        cp    trtbps      chol       fbs  \
# age       1.000000 -0.119247 -0.051933  0.271392  0.230342  0.104225
# sex      -0.119247  1.000000 -0.060716 -0.055145 -0.194537  0.032875
# cp       -0.051933 -0.060716  1.000000  0.076209 -0.116952  0.136897
# trtbps    0.271392 -0.055145  0.076209  1.000000  0.154767  0.147803
# chol      0.230342 -0.194537 -0.116952  0.154767  1.000000  0.026206
# fbs       0.104225  0.032875  0.136897  0.147803  0.026206  1.000000
# restecg  -0.118930 -0.046395  0.048991 -0.091274 -0.157267 -0.068650
# thalachh -0.393832 -0.055804  0.270027 -0.037539 -0.034098  0.012731
# exng      0.096686  0.138691 -0.352880  0.069059  0.098807  0.033408
# oldpeak   0.196713  0.112399 -0.123099  0.206422  0.064971 -0.018831
# slp      -0.162249 -0.051536  0.088000 -0.137430 -0.011561 -0.056229
# caa       0.299514  0.075655 -0.139966  0.086578  0.095680  0.122891
# thall     0.055172  0.216670 -0.190808  0.076119  0.114066 -0.004472
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
sns.countplot(df['output'])
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
sns.countplot(df['sex'])
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
sns.countplot(data=df,x=df['sex'], hue=df['output'])
plt.xticks([0,1],['Female','Male'])
plt.legend(labels=['No Disease' , 'Disease'])
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
sns.distplot(df['age'],bins=20)
plt.show
# Out:
# /tmp/ipython-input-3609531802.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'],bins=20)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.countplot(df['cp'])
plt.xticks([0,1,2,3],["Typical Angina","Atypical Angina","Non Anginal pain","Asymptomatic"])
plt.show()

# %%
sns.countplot(data=df,x='cp',hue='output')
plt.legend(labels=['No Disease' , 'Disease'])
plt.show()

# %%
df.columns
# Out:
# Index(['age', 'sex', 'cp', 'trtbps', 'chol', 'fbs', 'restecg', 'thalachh',
#        'exng', 'oldpeak', 'slp', 'caa', 'thall', 'output'],
#       dtype='object')

# %%
df['trtbps'].hist()
# Out:
# <Axes: >

# %%
df['chol'].hist()
# Out:
# <Axes: >
